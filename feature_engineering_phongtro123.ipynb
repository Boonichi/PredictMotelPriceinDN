# %%
#Include Libraries:
import pandas as pd
import pickle
import re
import numpy as np

# %%
pd.options.mode.chained_assignment = None
with open("save_house_phongtro123.pickle","rb") as handle:
    dataset = pickle.load(handle)
dataset = pd.DataFrame(data = dataset)
dataset.head()
# Out:
#                                             Location            Price  \
# 0  Địa chỉ: 408/4 Tôn Đức Thắng, Phường Hòa Minh,...  1.3 triệu/tháng
# 1  Địa chỉ: Phường Nại Hiên Đông, Quận Sơn Trà, Đ...    3 triệu/tháng
# 2  Địa chỉ: k123/97/58 Cù Chính Lan, Phường Hòa K...  1.5 triệu/tháng
# 3  Địa chỉ: Đường Vương Thừa Vũ, Phường An Hải Bắ...  2.6 triệu/tháng
# 4  Địa chỉ: 493 Tôn Đức Thắng, Phường Hòa Khánh N...  3.2 triệu/tháng
#
#                                                 Name  area         Feature0  \
# 0  Cho thuê phòng trọ đường Tôn Đức Thắng, Liên C...  20m2  Mã tin: #602257
# 1  Nhà biệt thự còn dư nhiều phòng cho thuê lâu d...  25m2  Mã tin: #602355
# 2  Cho thuê phòng trọ (riêng chủ) gần chợ, gần tr...  15m2  Mã tin: #589224
# 3  Cho thuê tại Ngã tư đường Vương Thừa Vũ + Trần...  30m2  Mã tin: #602082
# 4  Cho thuê phòng trọ full nội thất đẹp. Giá: từ ...  40m2  Mã tin: #602055
#
#                              Feature1                          Feature2  \
# 0  Khu vực Cho thuê phòng trọ Đà Nẵng  Loại tin rao: Phòng trọ, nhà trọ
# 1  Khu vực Cho thuê phòng trọ Đà Nẵng  Loại tin rao: Phòng trọ, nhà trọ
# 2  Khu vực Cho thuê phòng trọ Đà Nẵng  Loại tin rao: Phòng trọ, nhà trọ
# 3  Khu vực Cho thuê phòng trọ Đà Nẵng  Loại tin rao: Phòng trọ, nhà trọ
# 4  Khu vực Cho thuê phòng trọ Đà Nẵng  Loại tin rao: Phòng trọ, nhà trọ
#
#                  Feature3             Feature4  \
# 0  Đối tượng thuê: Tất cả   Gói tin: Tin VIP 3
# 1  Đối tượng thuê: Tất cả  Gói tin: Tin thường
# 2  Đối tượng thuê: Tất cả  Gói tin: Tin thường
# 3  Đối tượng thuê: Tất cả  Gói tin: Tin thường
# 4  Đối tượng thuê: Tất cả  Gói tin: Tin thường
#
#                                 Feature5  \
# 0  Ngày đăng: Chủ Nhật, 14:10 12/06/2022
# 1     Ngày đăng: Thứ 3, 08:31 14/06/2022
# 2     Ngày đăng: Thứ 5, 11:25 09/06/2022
# 3     Ngày đăng: Thứ 5, 09:16 09/06/2022
# 4     Ngày đăng: Thứ 4, 14:35 08/06/2022
#
#                                    Feature6                    Feature7  \
# 0     Ngày hết hạn: Thứ 6, 14:10 17/06/2022  Liên hệ: NGUYỄN HOÀNG ĐIỀN
# 1     Ngày hết hạn: Thứ 6, 08:31 24/06/2022        Liên hệ: Hoàng Hương
# 2  Ngày hết hạn: Chủ Nhật, 11:25 19/06/2022     Liên hệ: Phạm Thái Bình
# 3  Ngày hết hạn: Chủ Nhật, 09:16 19/06/2022     Liên hệ: Tăng Thùy Trâm
# 4     Ngày hết hạn: Thứ 7, 14:35 18/06/2022    Liên hệ: Đinh Thùy Dương
#
#                  Feature8         Feature9 Feature10
# 0  Điện thoại: 0934050705  Zalo 0934050705       NaN
# 1  Điện thoại: 0983293294  Zalo 0983293294       NaN
# 2  Điện thoại: 0905159986  Zalo 0905159986       NaN
# 3  Điện thoại: 0935993328  Zalo 0935993328       NaN
# 4  Điện thoại: 0983283515  Zalo 0983283515       NaN

# %%
dataset = dataset.drop(columns = ['Feature0','Feature1','Feature7','Feature8','Feature9'])
dataset.head()
# Out:
#                                             Location            Price  \
# 0  Địa chỉ: 408/4 Tôn Đức Thắng, Phường Hòa Minh,...  1.3 triệu/tháng
# 1  Địa chỉ: Phường Nại Hiên Đông, Quận Sơn Trà, Đ...    3 triệu/tháng
# 2  Địa chỉ: k123/97/58 Cù Chính Lan, Phường Hòa K...  1.5 triệu/tháng
# 3  Địa chỉ: Đường Vương Thừa Vũ, Phường An Hải Bắ...  2.6 triệu/tháng
# 4  Địa chỉ: 493 Tôn Đức Thắng, Phường Hòa Khánh N...  3.2 triệu/tháng
#
#                                                 Name  area  \
# 0  Cho thuê phòng trọ đường Tôn Đức Thắng, Liên C...  20m2
# 1  Nhà biệt thự còn dư nhiều phòng cho thuê lâu d...  25m2
# 2  Cho thuê phòng trọ (riêng chủ) gần chợ, gần tr...  15m2
# 3  Cho thuê tại Ngã tư đường Vương Thừa Vũ + Trần...  30m2
# 4  Cho thuê phòng trọ full nội thất đẹp. Giá: từ ...  40m2
#
#                            Feature2                Feature3  \
# 0  Loại tin rao: Phòng trọ, nhà trọ  Đối tượng thuê: Tất cả
# 1  Loại tin rao: Phòng trọ, nhà trọ  Đối tượng thuê: Tất cả
# 2  Loại tin rao: Phòng trọ, nhà trọ  Đối tượng thuê: Tất cả
# 3  Loại tin rao: Phòng trọ, nhà trọ  Đối tượng thuê: Tất cả
# 4  Loại tin rao: Phòng trọ, nhà trọ  Đối tượng thuê: Tất cả
#
#               Feature4                               Feature5  \
# 0   Gói tin: Tin VIP 3  Ngày đăng: Chủ Nhật, 14:10 12/06/2022
# 1  Gói tin: Tin thường     Ngày đăng: Thứ 3, 08:31 14/06/2022
# 2  Gói tin: Tin thường     Ngày đăng: Thứ 5, 11:25 09/06/2022
# 3  Gói tin: Tin thường     Ngày đăng: Thứ 5, 09:16 09/06/2022
# 4  Gói tin: Tin thường     Ngày đăng: Thứ 4, 14:35 08/06/2022
#
#                                    Feature6 Feature10
# 0     Ngày hết hạn: Thứ 6, 14:10 17/06/2022       NaN
# 1     Ngày hết hạn: Thứ 6, 08:31 24/06/2022       NaN
# 2  Ngày hết hạn: Chủ Nhật, 11:25 19/06/2022       NaN
# 3  Ngày hết hạn: Chủ Nhật, 09:16 19/06/2022       NaN
# 4     Ngày hết hạn: Thứ 7, 14:35 18/06/2022       NaN

# %%
regex = "[(\d\W)*\d+]+(triệu|tỷ|đ)+"
x = '1.3 triệu/tháng'
result = re.match(regex,x)
print(result[0])
# Out:
# 1.3 triệu

# %%
#Regex for extracting useful information
price_re = "([(\d\W)*\d+]+(triệu|tỷ|đ)+)?(thoả thuận)?"
price_stn = "(\d+)\W*(\d*) (triệu|đ)"
location_re = "[Phường|Xã]+((\W\w+)+), [Quận|Huyện]+((\W\w+)+)"
area_re = "\d+"
deposit_fee = "\d+"
furniture_re = "Nội thất đầy đủ|Nhà trống"

#Modifying the dataframe
dataset['Price'] = dataset['Price'].apply(lambda x: re.match(price_re,x)[0])
dataset = dataset[dataset['Price'].str.contains("tỷ") == False]
dataset = dataset.reset_index(drop = True)
dataset['Ward'] = dataset['Location'].apply(lambda x: list(re.findall(location_re,x)[0])[0])
dataset['District'] = dataset['Location'].apply(lambda x: list(re.findall(location_re,x)[0])[2])
#dataset['Feature1'] = dataset['Feature1'].apply(lambda x: re.findall(area_re,x)[0])
#for i in range(len(dataset['Feature3'])):
#    try:
#        dataset['Feature3'][i] = int(''.join(re.findall(deposit_fee,dataset['Feature3'][i])))
#    except: pass
#for i in range(len(dataset['Feature2'])):
#    try:
#        dataset['Feature2'][i] = re.findall(furniture_re,dataset['Feature2'][i])[0]
#    except: pass
#for i in range(len(dataset['Price'])):
#    price_components = list(re.findall(price_stn,dataset['Price'][i])[0])
#    if (price_components[2] == 'triệu'):
#        if (price_components[1] != ''):
#            dataset['Price'][i] = int(float(price_components[0]) * 1000000 + float(str(0.) + price_components[1]) * 10000000)
#        else: dataset['Price'][i] = int(float(price_components[0]) * 1000000)
#    else:
#        dataset['Price'][i] = int(float(''.join([price_components[0],price_components[1]])))
dataset.to_csv('Modified_Dataset_phongtro123.csv')
dataset.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/2r/vgdn5c2j5fb567xb2nm5_qfm0000gn/T/ipykernel_31533/1213188939.py in <module>
#      11 dataset = dataset[dataset['Price'].str.contains("tỷ") == False]
#      12 dataset = dataset.reset_index(drop = True)
# ---> 13 dataset['Ward'] = dataset['Location'].apply(lambda x: list(re.findall(location_re,x)[0])[0])
#      14 dataset['District'] = dataset['Location'].apply(lambda x: list(re.findall(location_re,x)[0])[2])
#      15 #dataset['Feature1'] = dataset['Feature1'].apply(lambda x: re.findall(area_re,x)[0])
#
# ~/miniforge3/envs/tfvenv/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /var/folders/2r/vgdn5c2j5fb567xb2nm5_qfm0000gn/T/ipykernel_31533/1213188939.py in <lambda>(x)
#      11 dataset = dataset[dataset['Price'].str.contains("tỷ") == False]
#      12 dataset = dataset.reset_index(drop = True)
# ---> 13 dataset['Ward'] = dataset['Location'].apply(lambda x: list(re.findall(location_re,x)[0])[0])
#      14 dataset['District'] = dataset['Location'].apply(lambda x: list(re.findall(location_re,x)[0])[2])
#      15 #dataset['Feature1'] = dataset['Feature1'].apply(lambda x: re.findall(area_re,x)[0])
#
# IndexError: list index out of range
