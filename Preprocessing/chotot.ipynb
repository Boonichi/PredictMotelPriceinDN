# %%
#Include Libraries
import pandas as pd
import pickle
import re
import numpy as np

# %%
pd.options.mode.chained_assignment = None 
with open('../Raw_Data/chotot.pickle','rb') as handle:
    dataset = pickle.load(handle)
dataset.head()
# Out:
#                                             Location                   Price  \
# 0  17, Cẩm Băc 8, Phường Hòa Thọ Đông, Quận Cẩm L...  1,6 triệu/tháng- 20 m2
# 1  132, Ba Tháng Hai, Phường Thuận Phước, Quận Hả...  1,1 triệu/tháng- 40 m2
# 2  K1120/58 Trường Chinh, Phường Hòa Phát, Quận C...  1,5 triệu/tháng- 20 m2
# 3  Trần Đăng, Phường Hòa Minh, Quận Liên Chiểu, Đ...  2,5 triệu/tháng- 25 m2
# 4  Cao Xuân Duc, Phường Thuận Phước, Quận Hải Châ...  1,2 triệu/tháng- 30 m2
#
#                                                 Name  \
# 0      Phòng trọ Cẩm Lệ, rộng rãi, sạch đẹp an ninh!
# 1          Trọ homestay-1.1tr-Điều hoà-Bao điện nước
# 2                         Phòng trọ Quận Cẩm Lệ 20m²
# 3  Phòng trọ Cao cấp25m² Kinh Dương Vương,Liên Chiểu
# 4                                       trọ homestay
#
#                              Date  Feature0          Feature1  \
# 0   Tin cá nhân đăng 2 tuần trước  Cho thuê  Diện tích: 20 m²
# 1   Tin cá nhân đăng 3 tuần trước  Cho thuê  Diện tích: 40 m²
# 2  Tin cá nhân đăng 4 tháng trước  Cho thuê  Diện tích: 20 m²
# 3    Tin cá nhân đăng 1 giờ trước  Cho thuê  Diện tích: 25 m²
# 4    Tin cá nhân đăng 2 giờ trước  Cho thuê  Diện tích: 30 m²
#
#                    Feature3                              Feature2
# 0    Số tiền cọc: 500.000 đ                                   NaN
# 1     Số tiền cọc: 50.000 đ  Tình trạng nội thất: Nội thất đầy đủ
# 2    Số tiền cọc: 500.000 đ        Tình trạng nội thất: Nhà trống
# 3  Số tiền cọc: 2.500.000 đ  Tình trạng nội thất: Nội thất đầy đủ
# 4  Số tiền cọc: 1.000.000 đ  Tình trạng nội thất: Nội thất đầy đủ

# %%
dataset[['Price','Feature1','Location','Feature2']]
# Out:
#                       Price  Feature0  \
# 0    1,6 triệu/tháng- 20 m2  Cho thuê
# 1    1,1 triệu/tháng- 40 m2  Cho thuê
# 2    1,5 triệu/tháng- 20 m2  Cho thuê
# 3    2,5 triệu/tháng- 25 m2  Cho thuê
# 4    1,2 triệu/tháng- 30 m2  Cho thuê
# ..                      ...       ...
# 771    1 triệu/tháng- 22 m2  Cho thuê
# 772  1,5 triệu/tháng- 20 m2  Cho thuê
# 773  1,8 triệu/tháng- 25 m2  Cho thuê
# 774  1,7 triệu/tháng- 28 m2  Cho thuê
# 775  1,3 triệu/tháng- 20 m2  Cho thuê
#
#                                               Location  \
# 0    17, Cẩm Băc 8, Phường Hòa Thọ Đông, Quận Cẩm L...
# 1    132, Ba Tháng Hai, Phường Thuận Phước, Quận Hả...
# 2    K1120/58 Trường Chinh, Phường Hòa Phát, Quận C...
# 3    Trần Đăng, Phường Hòa Minh, Quận Liên Chiểu, Đ...
# 4    Cao Xuân Duc, Phường Thuận Phước, Quận Hải Châ...
# ..                                                 ...
# 771           Phường Hòa Thọ Tây, Quận Cẩm Lệ, Đà Nẵng
# 772  K1120/58 Trường Chinh, Phường Hòa Phát, Quận C...
# 773  41, nhơn hoà 21, Phường Hòa An, Quận Cẩm Lệ, Đ...
# 774  Đường Ông Ích Khiêm, Phường Hải Châu II, Quận ...
# 775  47, 47 Nhơn Hoà 22, Phường Hòa An, Quận Cẩm Lệ...
#
#                                  Feature2
# 0                                     NaN
# 1    Tình trạng nội thất: Nội thất đầy đủ
# 2          Tình trạng nội thất: Nhà trống
# 3    Tình trạng nội thất: Nội thất đầy đủ
# 4    Tình trạng nội thất: Nội thất đầy đủ
# ..                                    ...
# 771        Tình trạng nội thất: Nhà trống
# 772        Tình trạng nội thất: Nhà trống
# 773                                   NaN
# 774  Tình trạng nội thất: Nội thất đầy đủ
# 775        Tình trạng nội thất: Nhà trống
#
# [776 rows x 4 columns]

# %%
reg = "(\d+)\W*(\d*) (triệu|đ)"
x = "500000 đ"
result = re.findall(reg,x)
print(result)
# Out:
# [('500000', '', 'đ')]

# %%
#Regex for extracting useful information
price_re = "[(\d\W)*\d+]+(triệu|tỷ|đ)+"
price_stn = "(\d+)\W*(\d*) (triệu|đ)"
location_re = "[Phường|Xã]+((\W\w+)+), [Quận|Huyện]+((\W\w+)+)"
area_re = "\d+"
deposit_fee = "\d+"
furniture_re = "Nội thất đầy đủ|Nhà trống|Nội thất cao cấp"
m_price = 1000000
#Modifying the dataframe
dataset['Price'] = dataset['Price'].apply(lambda x: re.match(price_re,x)[0])
dataset = dataset[dataset['Price'].str.contains("tỷ") == False]
dataset = dataset.reset_index(drop = True)
dataset['Ward'] = dataset['Location'].apply(lambda x: list(re.findall(location_re,x)[0])[0])
dataset['District'] = dataset['Location'].apply(lambda x: list(re.findall(location_re,x)[0])[2])
dataset['Feature1'] = dataset['Feature1'].apply(lambda x: re.findall(area_re,x)[0])
for i in range(len(dataset['Feature3'])):
    try:
        dataset['Feature3'][i] = int(''.join(re.findall(deposit_fee,dataset['Feature3'][i])))
    except: pass
for i in range(len(dataset['Feature2'])):
    try:
        dataset['Feature2'][i] = re.findall(furniture_re,dataset['Feature2'][i])[0]
    except: pass
for i in range(len(dataset['Price'])):
    price_components = list(re.findall(price_stn,dataset['Price'][i])[0])
    if (price_components[2] == 'triệu'):
        if (price_components[1] != ''):
            dataset['Price'][i] = int(float(price_components[0]) * m_price + float(str(0.) + price_components[1]) * 10000000)
        else: dataset['Price'][i] = int(float(price_components[0]) * m_price)
    else:
        dataset['Price'][i] = int(float(''.join([price_components[0],price_components[1]])))
dataset.head()
# Out:
#                                             Location    Price  \
# 0  17, Cẩm Băc 8, Phường Hòa Thọ Đông, Quận Cẩm L...  1600000
# 1  132, Ba Tháng Hai, Phường Thuận Phước, Quận Hả...  1100000
# 2  K1120/58 Trường Chinh, Phường Hòa Phát, Quận C...  1500000
# 3  Trần Đăng, Phường Hòa Minh, Quận Liên Chiểu, Đ...  2500000
# 4  Cao Xuân Duc, Phường Thuận Phước, Quận Hải Châ...  1200000
#
#                                                 Name  \
# 0      Phòng trọ Cẩm Lệ, rộng rãi, sạch đẹp an ninh!
# 1          Trọ homestay-1.1tr-Điều hoà-Bao điện nước
# 2                         Phòng trọ Quận Cẩm Lệ 20m²
# 3  Phòng trọ Cao cấp25m² Kinh Dương Vương,Liên Chiểu
# 4                                       trọ homestay
#
#                              Date  Feature0 Feature1 Feature3  \
# 0   Tin cá nhân đăng 2 tuần trước  Cho thuê       20   500000
# 1   Tin cá nhân đăng 3 tuần trước  Cho thuê       40    50000
# 2  Tin cá nhân đăng 4 tháng trước  Cho thuê       20   500000
# 3    Tin cá nhân đăng 1 giờ trước  Cho thuê       25  2500000
# 4    Tin cá nhân đăng 2 giờ trước  Cho thuê       30  1000000
#
#           Feature2           Ward     District
# 0              NaN   Hòa Thọ Đông       Cẩm Lệ
# 1  Nội thất đầy đủ    Thuận Phước     Hải Châu
# 2        Nhà trống       Hòa Phát       Cẩm Lệ
# 3  Nội thất đầy đủ       Hòa Minh   Liên Chiểu
# 4  Nội thất đầy đủ    Thuận Phước     Hải Châu

# %%
dataset = dataset.drop(columns = ['Location', 'Name', 'Date','Feature0'])
dataset = dataset.rename(columns = {"Feature1" :"Area", "Feature3" :"Deposit Fee", "Feature2" : "Furniture","Feature0" : "Đối tượng"})
dataset.head()
# Out:
#      Price Area Deposit Fee        Furniture           Ward     District
# 0  1600000   20      500000              NaN   Hòa Thọ Đông       Cẩm Lệ
# 1  1100000   40       50000  Nội thất đầy đủ    Thuận Phước     Hải Châu
# 2  1500000   20      500000        Nhà trống       Hòa Phát       Cẩm Lệ
# 3  2500000   25     2500000  Nội thất đầy đủ       Hòa Minh   Liên Chiểu
# 4  1200000   30     1000000  Nội thất đầy đủ    Thuận Phước     Hải Châu

# %%
dataset.to_csv('../Dataset/chotot.csv')
